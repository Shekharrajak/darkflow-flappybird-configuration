# %%
# !git clone https://github.com/Shekharrajak/darkflow-flappybird-configuration
# Out:
# Cloning into 'darkflow-flappybird-configuration'...
# remote: Enumerating objects: 197, done.
# remote: Counting objects: 100% (197/197), done.
# remote: Compressing objects: 100% (137/137), done.
# remote: Total 197 (delta 65), reused 183 (delta 55), pack-reused 0
# Receiving objects: 100% (197/197), 22.60 MiB | 50.74 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
# !cd darkflow-flappybird-configuration && python3 setup.py build_ext --inplace
# Out:
# Compiling darkflow/cython_utils/nms.pyx because it changed.
# Compiling darkflow/cython_utils/cy_yolo2_findboxes.pyx because it changed.
# Compiling darkflow/cython_utils/cy_yolo_findboxes.pyx because it changed.
# [1/3] Cythonizing darkflow/cython_utils/cy_yolo2_findboxes.pyx
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/darkflow-flappybird-configuration/darkflow/cython_utils/cy_yolo2_findboxes.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# [2/3] Cythonizing darkflow/cython_utils/cy_yolo_findboxes.pyx
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/darkflow-flappybird-configuration/darkflow/cython_utils/cy_yolo_findboxes.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# [3/3] Cythonizing darkflow/cython_utils/nms.pyx
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/darkflow-flappybird-configuration/darkflow/cython_utils/nms.pxd
#   tree = Parsing.p_module(s, pxd, full_module_name)
# running build_ext
# building 'darkflow.cython_utils.nms' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# creating build/temp.linux-x86_64-3.6/darkflow
# creating build/temp.linux-x86_64-3.6/darkflow/cython_utils
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/numpy/core/include -I/usr/include/python3.6m -c darkflow/cython_utils/nms.c -o build/temp.linux-x86_64-3.6/darkflow/cython_utils/nms.o
# In file included from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1822:0,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from darkflow/cython_utils/nms.c:615:
# /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it with " \
#   ^~~~~~~
# creating build/lib.linux-x86_64-3.6
# creating build/lib.linux-x86_64-3.6/darkflow
# creating build/lib.linux-x86_64-3.6/darkflow/cython_utils
# x86_64-linux-gnu-gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.6/darkflow/cython_utils/nms.o -lm -o build/lib.linux-x86_64-3.6/darkflow/cython_utils/nms.cpython-36m-x86_64-linux-gnu.so
# building 'darkflow.cython_utils.cy_yolo2_findboxes' extension
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/numpy/core/include -I/usr/include/python3.6m -c darkflow/cython_utils/cy_yolo2_findboxes.c -o build/temp.linux-x86_64-3.6/darkflow/cython_utils/cy_yolo2_findboxes.o
# In file included from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1822:0,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from darkflow/cython_utils/cy_yolo2_findboxes.c:615:
# /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it with " \
#   ^~~~~~~
# x86_64-linux-gnu-gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.6/darkflow/cython_utils/cy_yolo2_findboxes.o -lm -o build/lib.linux-x86_64-3.6/darkflow/cython_utils/cy_yolo2_findboxes.cpython-36m-x86_64-linux-gnu.so
# building 'darkflow.cython_utils.cy_yolo_findboxes' extension
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/numpy/core/include -I/usr/include/python3.6m -c darkflow/cython_utils/cy_yolo_findboxes.c -o build/temp.linux-x86_64-3.6/darkflow/cython_utils/cy_yolo_findboxes.o
# In file included from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1822:0,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from darkflow/cython_utils/cy_yolo_findboxes.c:615:
# /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it with " \
#   ^~~~~~~
# x86_64-linux-gnu-gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.6/darkflow/cython_utils/cy_yolo_findboxes.o -lm -o build/lib.linux-x86_64-3.6/darkflow/cython_utils/cy_yolo_findboxes.cpython-36m-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-3.6/darkflow/cython_utils/nms.cpython-36m-x86_64-linux-gnu.so -> darkflow/cython_utils
# copying build/lib.linux-x86_64-3.6/darkflow/cython_utils/cy_yolo2_findboxes.cpython-36m-x86_64-linux-gnu.so -> darkflow/cython_utils
# copying build/lib.linux-x86_64-3.6/darkflow/cython_utils/cy_yolo_findboxes.cpython-36m-x86_64-linux-gnu.so -> darkflow/cython_utils

# %%
# !cd darkflow-flappybird-configuration && pip install -e .
# Out:
# Obtaining file:///content/darkflow-flappybird-configuration
# Installing collected packages: darkflow
#   Running setup.py develop for darkflow
# Successfully installed darkflow

# %%
# !mkdir darkflow-flappybird-configuration/bin

# %%
# !cd darkflow-flappybird-configuration && python flow --model cfg/tiny-yolo-voc-3c.cfg --load bin/tiny-yolo-voc.weights --train --annotation new_model_data/annotations_flappybird_pipes --dataset new_model_data/images  --gpu 1.0
# Out:
# Parsing ./cfg/tiny-yolo-voc.cfg
# Parsing cfg/tiny-yolo-voc-3c.cfg
# Loading bin/tiny-yolo-voc.weights ...
# Successfully identified 63471556 bytes
# Finished in 0.003854990005493164s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
#        |        | input                            | (?, 416, 416, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 16)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 16)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 52, 52, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 26, 26, 128)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 26, 26, 256)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 13, 13, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 512)
#  Load  |  Yep!  | maxp 2x2p0_1                     | (?, 13, 13, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Init  |  Yep!  | conv 1x1p0_1    linear           | (?, 13, 13, 40)
# -------+--------+----------------------------------+---------------
# GPU mode with 1.0 usage
# cfg/tiny-yolo-voc-3c.cfg loss hyper-parameters:
# 	H       = 13
# 	W       = 13
# 	box     = 5
# 	classes = 3
# 	scales  = [1.0, 5.0, 1.0, 1.0]
# WARNING:tensorflow:From /content/darkflow-flappybird-configuration/darkflow/net/yolov2/train.py:87: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Building cfg/tiny-yolo-voc-3c.cfg loss
# Building cfg/tiny-yolo-voc-3c.cfg train op
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 2019-05-05 10:57:23.533834: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-05-05 10:57:23.534121: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2e2e260 executing computations on platform Host. Devices:
# 2019-05-05 10:57:23.534156: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-05-05 10:57:23.697447: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-05-05 10:57:23.698030: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2e2de40 executing computations on platform CUDA. Devices:
# 2019-05-05 10:57:23.698060: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2019-05-05 10:57:23.698441: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# totalMemory: 14.73GiB freeMemory: 14.60GiB
# 2019-05-05 10:57:23.698468: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-05-05 10:57:25.127070: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-05-05 10:57:25.127127: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-05-05 10:57:25.127140: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-05-05 10:57:25.127423: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-05-05 10:57:25.127517: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15079 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# Finished in 5.056979656219482s
#
# Enter training ...
#
# cfg/tiny-yolo-voc-3c.cfg parsing new_model_data/annotations_flappybird_pipes
# Parsing for ['flappybird', 'green-pipe-up', 'green-pipe-down']
# [====================>]100%  4.xml
# Statistics:
# green-pipe-down: 35
# flappybird: 14
# green-pipe-up: 34
# Dataset size: 14
# Dataset of 14 instance(s)
# Training statistics:
# 	Learning rate : 1e-05
# 	Batch size    : 14
# 	Epoch number  : 1000
# 	Backup every  : 2000
# step 1 - loss 102.06214904785156 - moving ave loss 102.06214904785156
# Finish 1 epoch(es)
# step 2 - loss 101.47566986083984 - moving ave loss 102.0035011291504
# Finish 2 epoch(es)
# step 3 - loss 99.56517791748047 - moving ave loss 101.75966880798342
# Finish 3 epoch(es)
# step 4 - loss 99.6584701538086 - moving ave loss 101.54954894256593
# Finish 4 epoch(es)
# step 5 - loss 98.99903869628906 - moving ave loss 101.29449791793826
# Finish 5 epoch(es)
# step 6 - loss 97.96092987060547 - moving ave loss 100.96114111320499
# Finish 6 epoch(es)
# step 7 - loss 97.75606536865234 - moving ave loss 100.64063353874973
# Finish 7 epoch(es)
# step 8 - loss 98.32969665527344 - moving ave loss 100.4095398504021
# Finish 8 epoch(es)
# step 9 - loss 96.96537017822266 - moving ave loss 100.06512288318416
# Finish 9 epoch(es)
# step 10 - loss 96.59855651855469 - moving ave loss 99.7184662467212
# Finish 10 epoch(es)
# step 11 - loss 96.13594818115234 - moving ave loss 99.36021444016431
# Finish 11 epoch(es)
# step 12 - loss 95.61439514160156 - moving ave loss 98.98563251030804
# Finish 12 epoch(es)
# step 13 - loss 94.87013244628906 - moving ave loss 98.57408250390614
# Finish 13 epoch(es)
# step 14 - loss 94.88496398925781 - moving ave loss 98.20517065244131
# Finish 14 epoch(es)
# step 15 - loss 94.51197814941406 - moving ave loss 97.83585140213859
# Finish 15 epoch(es)
# step 16 - loss 94.97504425048828 - moving ave loss 97.54977068697356
# Finish 16 epoch(es)
# step 17 - loss 93.85245513916016 - moving ave loss 97.18003913219222
# Finish 17 epoch(es)
# step 18 - loss 92.79700469970703 - moving ave loss 96.7417356889437
# Finish 18 epoch(es)
# step 19 - loss 92.97575378417969 - moving ave loss 96.3651374984673
# Finish 19 epoch(es)
# step 20 - loss 92.57523345947266 - moving ave loss 95.98614709456784
# Finish 20 epoch(es)
# step 21 - loss 91.82112121582031 - moving ave loss 95.5696445066931
# Finish 21 epoch(es)
# step 22 - loss 92.58146667480469 - moving ave loss 95.27082672350426
# Finish 22 epoch(es)
# step 23 - loss 90.97477722167969 - moving ave loss 94.8412217733218
# Finish 23 epoch(es)
# step 24 - loss 92.6607894897461 - moving ave loss 94.62317854496423
# Finish 24 epoch(es)
# step 25 - loss 90.66974639892578 - moving ave loss 94.22783533036039
# Finish 25 epoch(es)
# step 26 - loss 90.28311920166016 - moving ave loss 93.83336371749037
# Finish 26 epoch(es)
# step 27 - loss 90.20033264160156 - moving ave loss 93.4700606099015
# Finish 27 epoch(es)
# step 28 - loss 89.4200439453125 - moving ave loss 93.0650589434426
# Finish 28 epoch(es)
# step 29 - loss 88.84963989257812 - moving ave loss 92.64351703835615
# Finish 29 epoch(es)
# step 30 - loss 88.81366729736328 - moving ave loss 92.26053206425686
# Finish 30 epoch(es)
# step 31 - loss 88.57447814941406 - moving ave loss 91.89192667277258
# Finish 31 epoch(es)
# step 32 - loss 88.75908660888672 - moving ave loss 91.578642666384
# Finish 32 epoch(es)
# step 33 - loss 87.66120147705078 - moving ave loss 91.18689854745068
# Finish 33 epoch(es)
# step 34 - loss 87.55945587158203 - moving ave loss 90.82415427986382
# Finish 34 epoch(es)
# step 35 - loss 87.74415588378906 - moving ave loss 90.51615444025634
# Finish 35 epoch(es)
# step 36 - loss 86.58290100097656 - moving ave loss 90.12282909632837
# Finish 36 epoch(es)
# step 37 - loss 86.3052978515625 - moving ave loss 89.7410759718518
# Finish 37 epoch(es)
# step 38 - loss 85.22534942626953 - moving ave loss 89.28950331729357
# Finish 38 epoch(es)
# step 39 - loss 85.7905044555664 - moving ave loss 88.93960343112086
# Finish 39 epoch(es)
# step 40 - loss 85.16441345214844 - moving ave loss 88.56208443322362
# Finish 40 epoch(es)
# step 41 - loss 84.89969635009766 - moving ave loss 88.19584562491103
# Finish 41 epoch(es)
# step 42 - loss 84.40433502197266 - moving ave loss 87.8166945646172
# Finish 42 epoch(es)
# step 43 - loss 83.92408752441406 - moving ave loss 87.42743386059689
# Finish 43 epoch(es)
# step 44 - loss 84.30892181396484 - moving ave loss 87.1155826559337
# Finish 44 epoch(es)
# step 45 - loss 83.26174926757812 - moving ave loss 86.73019931709814
# Finish 45 epoch(es)
# step 46 - loss 82.27669525146484 - moving ave loss 86.2848489105348
# Finish 46 epoch(es)
# step 47 - loss 82.91248321533203 - moving ave loss 85.94761234101453
# Finish 47 epoch(es)
# step 48 - loss 82.8632583618164 - moving ave loss 85.63917694309472
# Finish 48 epoch(es)
# step 49 - loss 81.89378356933594 - moving ave loss 85.26463760571885
# Finish 49 epoch(es)
# step 50 - loss 81.24703216552734 - moving ave loss 84.86287706169969
# Finish 50 epoch(es)
# step 51 - loss 80.98561096191406 - moving ave loss 84.47515045172113
# Finish 51 epoch(es)
# step 52 - loss 80.51416778564453 - moving ave loss 84.07905218511348
# Finish 52 epoch(es)
# step 53 - loss 80.05267333984375 - moving ave loss 83.67641430058652
# Finish 53 epoch(es)
# step 54 - loss 80.77628326416016 - moving ave loss 83.38640119694388
# Finish 54 epoch(es)
# step 55 - loss 80.37345123291016 - moving ave loss 83.08510620054051
# Finish 55 epoch(es)
# step 56 - loss 78.44644165039062 - moving ave loss 82.62123974552551
# Finish 56 epoch(es)
# step 57 - loss 78.6386947631836 - moving ave loss 82.22298524729132
# Finish 57 epoch(es)
# step 58 - loss 77.57078552246094 - moving ave loss 81.75776527480829
# Finish 58 epoch(es)
# step 59 - loss 77.28532409667969 - moving ave loss 81.31052115699543
# Finish 59 epoch(es)
# step 60 - loss 77.38067626953125 - moving ave loss 80.91753666824901
# Finish 60 epoch(es)
# step 61 - loss 76.60607147216797 - moving ave loss 80.48639014864091
# Finish 61 epoch(es)
# step 62 - loss 78.68753814697266 - moving ave loss 80.30650494847409
# Finish 62 epoch(es)
# step 63 - loss 75.75050354003906 - moving ave loss 79.85090480763058
# Finish 63 epoch(es)
# step 64 - loss 76.63253021240234 - moving ave loss 79.52906734810776
# Finish 64 epoch(es)
# step 65 - loss 74.85366821289062 - moving ave loss 79.06152743458605
# Finish 65 epoch(es)
# step 66 - loss 74.9033203125 - moving ave loss 78.64570672237745
# Finish 66 epoch(es)
# step 67 - loss 74.73070526123047 - moving ave loss 78.25420657626276
# Finish 67 epoch(es)
# step 68 - loss 73.86241149902344 - moving ave loss 77.81502706853884
# Finish 68 epoch(es)
# step 69 - loss 73.09132385253906 - moving ave loss 77.34265674693886
# Finish 69 epoch(es)
# step 70 - loss 74.98719787597656 - moving ave loss 77.10711085984262
# Finish 70 epoch(es)
# step 71 - loss 73.24920654296875 - moving ave loss 76.72132042815524
# Finish 71 epoch(es)
# step 72 - loss 72.72371673583984 - moving ave loss 76.32156005892371
# Finish 72 epoch(es)
# step 73 - loss 72.19327545166016 - moving ave loss 75.90873159819735
# Finish 73 epoch(es)
# step 74 - loss 71.97992706298828 - moving ave loss 75.51585114467645
# Finish 74 epoch(es)
# step 75 - loss 71.58915710449219 - moving ave loss 75.12318174065803
# Finish 75 epoch(es)
# step 76 - loss 71.98388671875 - moving ave loss 74.80925223846722
# Finish 76 epoch(es)
# step 77 - loss 70.57914733886719 - moving ave loss 74.38624174850722
# Finish 77 epoch(es)
# step 78 - loss 70.26268768310547 - moving ave loss 73.97388634196705
# Finish 78 epoch(es)
# step 79 - loss 69.68949127197266 - moving ave loss 73.5454468349676
# Finish 79 epoch(es)
# step 80 - loss 68.92721557617188 - moving ave loss 73.08362370908804
# Finish 80 epoch(es)
# step 81 - loss 69.02704620361328 - moving ave loss 72.67796595854058
# Finish 81 epoch(es)
# step 82 - loss 69.62419128417969 - moving ave loss 72.3725884911045
# Finish 82 epoch(es)
# step 83 - loss 68.22422790527344 - moving ave loss 71.95775243252139
# Finish 83 epoch(es)
# step 84 - loss 67.87532806396484 - moving ave loss 71.54950999566573
# Finish 84 epoch(es)
# step 85 - loss 67.39720153808594 - moving ave loss 71.13427914990775
# Finish 85 epoch(es)
# step 86 - loss 66.54051971435547 - moving ave loss 70.67490320635252
# Finish 86 epoch(es)
# step 87 - loss 66.63642883300781 - moving ave loss 70.27105576901806
# Finish 87 epoch(es)
# step 88 - loss 66.56489562988281 - moving ave loss 69.90043975510454
# Finish 88 epoch(es)
# step 89 - loss 65.46003723144531 - moving ave loss 69.45639950273862
# Finish 89 epoch(es)
# step 90 - loss 64.98478698730469 - moving ave loss 69.00923825119523
# Finish 90 epoch(es)
# step 91 - loss 65.03752899169922 - moving ave loss 68.61206732524563
# Finish 91 epoch(es)
# step 92 - loss 64.27236938476562 - moving ave loss 68.17809753119764
# Finish 92 epoch(es)
# step 93 - loss 65.8768310546875 - moving ave loss 67.94797088354663
# Finish 93 epoch(es)
# step 94 - loss 63.72628402709961 - moving ave loss 67.52580219790192
# Finish 94 epoch(es)
# step 95 - loss 63.380455017089844 - moving ave loss 67.11126747982073
# Finish 95 epoch(es)
# step 96 - loss 63.00123977661133 - moving ave loss 66.70026470949979
# Finish 96 epoch(es)
# step 97 - loss 62.13228225708008 - moving ave loss 66.24346646425782
# Finish 97 epoch(es)
# step 98 - loss 62.43993377685547 - moving ave loss 65.86311319551758
# Finish 98 epoch(es)
# step 99 - loss 61.38987350463867 - moving ave loss 65.4157892264297
# Finish 99 epoch(es)
# step 100 - loss 60.97667694091797 - moving ave loss 64.97187799787852
# Finish 100 epoch(es)
# step 101 - loss 61.28848648071289 - moving ave loss 64.60353884616195
# Finish 101 epoch(es)
# step 102 - loss 60.88971710205078 - moving ave loss 64.23215667175083
# Finish 102 epoch(es)
# step 103 - loss 61.81033706665039 - moving ave loss 63.98997471124079
# Finish 103 epoch(es)
# step 104 - loss 60.00893020629883 - moving ave loss 63.591870260746596
# Finish 104 epoch(es)
# step 105 - loss 60.681480407714844 - moving ave loss 63.30083127544342
# Finish 105 epoch(es)
# step 106 - loss 58.81294631958008 - moving ave loss 62.852042779857086
# Finish 106 epoch(es)
# step 107 - loss 58.73919677734375 - moving ave loss 62.44075817960576
# Finish 107 epoch(es)
# step 108 - loss 58.71148681640625 - moving ave loss 62.06783104328581
# Finish 108 epoch(es)
# step 109 - loss 58.01068878173828 - moving ave loss 61.66211681713106
# Finish 109 epoch(es)
# step 110 - loss 57.79062271118164 - moving ave loss 61.27496740653611
# Finish 110 epoch(es)
# step 111 - loss 58.76810073852539 - moving ave loss 61.02428073973504
# Finish 111 epoch(es)
# step 112 - loss 56.44367980957031 - moving ave loss 60.56622064671856
# Finish 112 epoch(es)
# step 113 - loss 56.20705795288086 - moving ave loss 60.130304377334795
# Finish 113 epoch(es)
# step 114 - loss 56.446285247802734 - moving ave loss 59.76190246438159
# Finish 114 epoch(es)
# step 115 - loss 55.99310302734375 - moving ave loss 59.38502252067781
# Finish 115 epoch(es)
# step 116 - loss 54.88603210449219 - moving ave loss 58.93512347905925
# Finish 116 epoch(es)
# step 117 - loss 54.37224578857422 - moving ave loss 58.47883571001075
# Finish 117 epoch(es)
# step 118 - loss 54.4151611328125 - moving ave loss 58.072468252290925
# Finish 118 epoch(es)
# step 119 - loss 55.29783248901367 - moving ave loss 57.7950046759632
# Finish 119 epoch(es)
# step 120 - loss 54.22138595581055 - moving ave loss 57.43764280394793
# Finish 120 epoch(es)
# step 121 - loss 53.24261474609375 - moving ave loss 57.01813999816251
# Finish 121 epoch(es)
# step 122 - loss 53.90412139892578 - moving ave loss 56.70673813823883
# Finish 122 epoch(es)
# step 123 - loss 52.85708999633789 - moving ave loss 56.32177332404874
# Finish 123 epoch(es)
# step 124 - loss 53.36103820800781 - moving ave loss 56.02569981244465
# Finish 124 epoch(es)
# step 125 - loss 51.9822883605957 - moving ave loss 55.621358667259756
# Finish 125 epoch(es)
# step 126 - loss 51.77354049682617 - moving ave loss 55.2365768502164
# Finish 126 epoch(es)
# step 127 - loss 51.36600875854492 - moving ave loss 54.84952004104925
# Finish 127 epoch(es)
# step 128 - loss 52.04928207397461 - moving ave loss 54.56949624434179
# Finish 128 epoch(es)
# step 129 - loss 50.7587890625 - moving ave loss 54.188425526157616
# Finish 129 epoch(es)
# step 130 - loss 50.55765914916992 - moving ave loss 53.82534888845885
# Finish 130 epoch(es)
# step 131 - loss 50.80896759033203 - moving ave loss 53.52371075864617
# Finish 131 epoch(es)
# step 132 - loss 49.26133728027344 - moving ave loss 53.097473410808895
# Finish 132 epoch(es)
# step 133 - loss 49.33047866821289 - moving ave loss 52.7207739365493
# Finish 133 epoch(es)
# step 134 - loss 49.913818359375 - moving ave loss 52.44007837883187
# Finish 134 epoch(es)
# step 135 - loss 48.66809844970703 - moving ave loss 52.062880385919385
# Finish 135 epoch(es)
# step 136 - loss 48.22592544555664 - moving ave loss 51.67918489188311
# Finish 136 epoch(es)
# step 137 - loss 48.75905990600586 - moving ave loss 51.38717239329539
# Finish 137 epoch(es)
# step 138 - loss 48.09328079223633 - moving ave loss 51.05778323318948
# Finish 138 epoch(es)
# step 139 - loss 48.22475051879883 - moving ave loss 50.77447996175042
# Finish 139 epoch(es)
# step 140 - loss 46.179561614990234 - moving ave loss 50.31498812707441
# Finish 140 epoch(es)
# step 141 - loss 46.07402038574219 - moving ave loss 49.89089135294119
# Finish 141 epoch(es)
# step 142 - loss 46.380435943603516 - moving ave loss 49.53984581200743
# Checkpoint at step 142
# Finish 142 epoch(es)
# step 143 - loss 46.94097137451172 - moving ave loss 49.27995836825786
# Finish 143 epoch(es)
# step 144 - loss 45.45027542114258 - moving ave loss 48.89699007354633
# Finish 144 epoch(es)
# step 145 - loss 45.55478286743164 - moving ave loss 48.562769352934865
# Finish 145 epoch(es)
# step 146 - loss 45.70354080200195 - moving ave loss 48.276846497841575
# Finish 146 epoch(es)
# step 147 - loss 44.56006622314453 - moving ave loss 47.905168470371876
# Finish 147 epoch(es)
# step 148 - loss 44.02898406982422 - moving ave loss 47.51755003031711
# Finish 148 epoch(es)
# step 149 - loss 44.03555679321289 - moving ave loss 47.169350706606686
# Finish 149 epoch(es)
# step 150 - loss 44.6590576171875 - moving ave loss 46.91832139766477
# Finish 150 epoch(es)
# step 151 - loss 43.068641662597656 - moving ave loss 46.53335342415806
# Finish 151 epoch(es)
# step 152 - loss 42.71209716796875 - moving ave loss 46.151227798539125
# Finish 152 epoch(es)
# step 153 - loss 42.31085205078125 - moving ave loss 45.767190223763336
# Finish 153 epoch(es)
# step 154 - loss 42.46855163574219 - moving ave loss 45.43732636496122
# Finish 154 epoch(es)
# step 155 - loss 41.836063385009766 - moving ave loss 45.07720006696608
# Finish 155 epoch(es)
# step 156 - loss 44.102256774902344 - moving ave loss 44.9797057377597
# Finish 156 epoch(es)
# step 157 - loss 41.38278579711914 - moving ave loss 44.62001374369565
# Finish 157 epoch(es)
# step 158 - loss 41.58029556274414 - moving ave loss 44.3160419256005
# Finish 158 epoch(es)
# step 159 - loss 41.28858947753906 - moving ave loss 44.013296680794355
# Finish 159 epoch(es)
# step 160 - loss 40.16627883911133 - moving ave loss 43.628594896626055
# Finish 160 epoch(es)
# step 161 - loss 41.035194396972656 - moving ave loss 43.369254846660716
# Finish 161 epoch(es)
# step 162 - loss 39.546669006347656 - moving ave loss 42.98699626262941
# Finish 162 epoch(es)
# step 163 - loss 39.49596405029297 - moving ave loss 42.63789304139577
# Finish 163 epoch(es)
# step 164 - loss 39.12826919555664 - moving ave loss 42.286930656811855
# Finish 164 epoch(es)
# step 165 - loss 39.15085983276367 - moving ave loss 41.97332357440704
# Finish 165 epoch(es)
# step 166 - loss 38.602134704589844 - moving ave loss 41.63620468742533
# Finish 166 epoch(es)
# step 167 - loss 38.3674430847168 - moving ave loss 41.30932852715448
# Finish 167 epoch(es)
# step 168 - loss 38.17702865600586 - moving ave loss 40.99609854003962
# Finish 168 epoch(es)
# step 169 - loss 37.433815002441406 - moving ave loss 40.6398701862798
# Finish 169 epoch(es)
# step 170 - loss 36.945716857910156 - moving ave loss 40.27045485344284
# Finish 170 epoch(es)
# step 171 - loss 37.23139953613281 - moving ave loss 39.966549321711845
# Finish 171 epoch(es)
# step 172 - loss 37.48904037475586 - moving ave loss 39.718798427016246
# Finish 172 epoch(es)
# step 173 - loss 36.92023468017578 - moving ave loss 39.4389420523322
# Finish 173 epoch(es)
# step 174 - loss 37.85135269165039 - moving ave loss 39.28018311626402
# Finish 174 epoch(es)
# step 175 - loss 36.034969329833984 - moving ave loss 38.955661737621014
# Finish 175 epoch(es)
# step 176 - loss 35.60817337036133 - moving ave loss 38.62091290089505
# Finish 176 epoch(es)
# step 177 - loss 35.40029525756836 - moving ave loss 38.298851136562384
# Finish 177 epoch(es)
# step 178 - loss 37.10797882080078 - moving ave loss 38.179763904986224
# Finish 178 epoch(es)
# step 179 - loss 35.06688690185547 - moving ave loss 37.86847620467315
# Finish 179 epoch(es)
# step 180 - loss 35.206199645996094 - moving ave loss 37.60224854880545
# Finish 180 epoch(es)
# step 181 - loss 34.63199234008789 - moving ave loss 37.3052229279337
# Finish 181 epoch(es)
# step 182 - loss 35.478904724121094 - moving ave loss 37.12259110755244
# Finish 182 epoch(es)
# step 183 - loss 34.91391372680664 - moving ave loss 36.901723369477864
# Finish 183 epoch(es)
# step 184 - loss 33.63998031616211 - moving ave loss 36.575549064146294
# Finish 184 epoch(es)
# step 185 - loss 33.33628463745117 - moving ave loss 36.25162262147678
# Finish 185 epoch(es)
# step 186 - loss 33.33818054199219 - moving ave loss 35.96027841352832
# Finish 186 epoch(es)
# step 187 - loss 32.983524322509766 - moving ave loss 35.66260300442647
# Finish 187 epoch(es)
# step 188 - loss 33.187564849853516 - moving ave loss 35.41509918896918
# Finish 188 epoch(es)
# step 189 - loss 33.508609771728516 - moving ave loss 35.224450247245116
# Finish 189 epoch(es)
# step 190 - loss 32.17171859741211 - moving ave loss 34.91917708226182
# Finish 190 epoch(es)
# step 191 - loss 31.83467674255371 - moving ave loss 34.610727048291004
# Finish 191 epoch(es)
# step 192 - loss 31.764047622680664 - moving ave loss 34.32605910572997
# Finish 192 epoch(es)
# step 193 - loss 31.406007766723633 - moving ave loss 34.03405397182934
# Finish 193 epoch(es)
# step 194 - loss 32.291255950927734 - moving ave loss 33.859774169739175
# Finish 194 epoch(es)
# step 195 - loss 32.338993072509766 - moving ave loss 33.70769606001624
# Finish 195 epoch(es)
# step 196 - loss 31.131132125854492 - moving ave loss 33.45003966660006
# Finish 196 epoch(es)
# step 197 - loss 30.818483352661133 - moving ave loss 33.18688403520617
# Finish 197 epoch(es)
# step 198 - loss 31.391983032226562 - moving ave loss 33.00739393490821
# Finish 198 epoch(es)
# step 199 - loss 30.15305519104004 - moving ave loss 32.7219600605214
# Finish 199 epoch(es)
# step 200 - loss 29.896472930908203 - moving ave loss 32.43941134756008
# Finish 200 epoch(es)
# step 201 - loss 29.785402297973633 - moving ave loss 32.174010442601435
# Finish 201 epoch(es)
# step 202 - loss 30.053966522216797 - moving ave loss 31.962006050562973
# Finish 202 epoch(es)
# step 203 - loss 29.83452033996582 - moving ave loss 31.749257479503257
# Finish 203 epoch(es)
# step 204 - loss 29.581687927246094 - moving ave loss 31.53250052427754
# Finish 204 epoch(es)
# step 205 - loss 28.701860427856445 - moving ave loss 31.24943651463543
# Finish 205 epoch(es)
# step 206 - loss 28.81791114807129 - moving ave loss 31.006283977979017
# Finish 206 epoch(es)
# step 207 - loss 28.7160587310791 - moving ave loss 30.777261453289025
# Finish 207 epoch(es)
# step 208 - loss 28.2788028717041 - moving ave loss 30.527415595130535
# Finish 208 epoch(es)
# step 209 - loss 28.11483383178711 - moving ave loss 30.286157418796193
# Finish 209 epoch(es)
# step 210 - loss 28.41444206237793 - moving ave loss 30.098985883154366
# Finish 210 epoch(es)
# step 211 - loss 27.085847854614258 - moving ave loss 29.797672080300355
# Finish 211 epoch(es)
# step 212 - loss 27.863605499267578 - moving ave loss 29.604265422197077
# Finish 212 epoch(es)
# step 213 - loss 27.673240661621094 - moving ave loss 29.41116294613948
# Finish 213 epoch(es)
# step 214 - loss 27.219552993774414 - moving ave loss 29.192001950902974
# Finish 214 epoch(es)
# step 215 - loss 28.48544692993164 - moving ave loss 29.12134644880584
# Finish 215 epoch(es)
# step 216 - loss 27.126140594482422 - moving ave loss 28.9218258633735
# Finish 216 epoch(es)
# step 217 - loss 26.761798858642578 - moving ave loss 28.70582316290041
# Finish 217 epoch(es)
# step 218 - loss 27.556781768798828 - moving ave loss 28.59091902349025
# Finish 218 epoch(es)
# step 219 - loss 26.178354263305664 - moving ave loss 28.349662547471794
# Finish 219 epoch(es)
# step 220 - loss 26.2782039642334 - moving ave loss 28.142516689147953
# Finish 220 epoch(es)
# step 221 - loss 26.830167770385742 - moving ave loss 28.01128179727173
# Finish 221 epoch(es)
# step 222 - loss 25.819015502929688 - moving ave loss 27.79205516783753
# Finish 222 epoch(es)
# step 223 - loss 25.872421264648438 - moving ave loss 27.60009177751862
# Finish 223 epoch(es)
# step 224 - loss 25.260746002197266 - moving ave loss 27.366157199986485
# Finish 224 epoch(es)
# step 225 - loss 25.3742618560791 - moving ave loss 27.166967665595745
# Finish 225 epoch(es)
# step 226 - loss 25.11079978942871 - moving ave loss 26.96135087797904
# Finish 226 epoch(es)
# step 227 - loss 24.808340072631836 - moving ave loss 26.74604979744432
# Finish 227 epoch(es)
# step 228 - loss 24.571002960205078 - moving ave loss 26.528545113720398
# Finish 228 epoch(es)
# step 229 - loss 24.39886474609375 - moving ave loss 26.315577076957737
# Finish 229 epoch(es)
# step 230 - loss 24.43485450744629 - moving ave loss 26.127504820006592
# Finish 230 epoch(es)
# step 231 - loss 24.613428115844727 - moving ave loss 25.976097149590405
# Finish 231 epoch(es)
# step 232 - loss 24.565073013305664 - moving ave loss 25.83499473596193
# Finish 232 epoch(es)
# step 233 - loss 26.454729080200195 - moving ave loss 25.89696817038576
# Finish 233 epoch(es)
# step 234 - loss 23.94293212890625 - moving ave loss 25.70156456623781
# Finish 234 epoch(es)
# step 235 - loss 23.381437301635742 - moving ave loss 25.4695518397776
# Finish 235 epoch(es)
# step 236 - loss 23.29903793334961 - moving ave loss 25.252500449134804
# Finish 236 epoch(es)
# step 237 - loss 23.472869873046875 - moving ave loss 25.07453739152601
# Finish 237 epoch(es)
# step 238 - loss 23.08817481994629 - moving ave loss 24.87590113436804
# Finish 238 epoch(es)
# step 239 - loss 23.27986717224121 - moving ave loss 24.716297738155358
# Finish 239 epoch(es)
# step 240 - loss 22.51026153564453 - moving ave loss 24.495694117904275
# Finish 240 epoch(es)
# step 241 - loss 23.929767608642578 - moving ave loss 24.439101466978105
# Finish 241 epoch(es)
# step 242 - loss 22.46232795715332 - moving ave loss 24.241424115995628
# Finish 242 epoch(es)
# step 243 - loss 22.17526626586914 - moving ave loss 24.03480833098298
# Finish 243 epoch(es)
# step 244 - loss 23.97409439086914 - moving ave loss 24.028736936971598
# Finish 244 epoch(es)
# step 245 - loss 22.185556411743164 - moving ave loss 23.844418884448753
# Finish 245 epoch(es)
# step 246 - loss 21.758277893066406 - moving ave loss 23.63580478531052
# Finish 246 epoch(es)
# step 247 - loss 21.75531005859375 - moving ave loss 23.447755312638844
# Finish 247 epoch(es)
# step 248 - loss 21.43187141418457 - moving ave loss 23.246166922793417
# Finish 248 epoch(es)
# step 249 - loss 21.173397064208984 - moving ave loss 23.038889936934975
# Finish 249 epoch(es)
# step 250 - loss 21.401147842407227 - moving ave loss 22.8751157274822
# Finish 250 epoch(es)
# step 251 - loss 20.88344383239746 - moving ave loss 22.675948537973728
# Finish 251 epoch(es)
# step 252 - loss 21.406585693359375 - moving ave loss 22.54901225351229
# Finish 252 epoch(es)
# step 253 - loss 20.93199920654297 - moving ave loss 22.387310948815358
# Finish 253 epoch(es)
# step 254 - loss 20.51011085510254 - moving ave loss 22.199590939444075
# Finish 254 epoch(es)
# step 255 - loss 20.72347640991211 - moving ave loss 22.05197948649088
# Finish 255 epoch(es)
# step 256 - loss 20.78382682800293 - moving ave loss 21.925164220642085
# Finish 256 epoch(es)
# step 257 - loss 21.836978912353516 - moving ave loss 21.916345689813227
# Finish 257 epoch(es)
# step 258 - loss 22.273935317993164 - moving ave loss 21.95210465263122
# Finish 258 epoch(es)
# step 259 - loss 20.04182243347168 - moving ave loss 21.761076430715267
# Finish 259 epoch(es)
# step 260 - loss 21.588695526123047 - moving ave loss 21.743838340256048
# Finish 260 epoch(es)
# step 261 - loss 20.235055923461914 - moving ave loss 21.592960098576633
# Finish 261 epoch(es)
# step 262 - loss 19.794645309448242 - moving ave loss 21.413128619663794
# Finish 262 epoch(es)
# step 263 - loss 19.497095108032227 - moving ave loss 21.22152526850064
# Finish 263 epoch(es)
# step 264 - loss 19.520605087280273 - moving ave loss 21.051433250378604
# Finish 264 epoch(es)
# step 265 - loss 19.415517807006836 - moving ave loss 20.887841706041428
# Finish 265 epoch(es)
# step 266 - loss 18.620040893554688 - moving ave loss 20.661061624792755
# Finish 266 epoch(es)
# step 267 - loss 19.20807647705078 - moving ave loss 20.515763110018558
# Finish 267 epoch(es)
# step 268 - loss 19.09903335571289 - moving ave loss 20.37409013458799
# Finish 268 epoch(es)
# step 269 - loss 19.617950439453125 - moving ave loss 20.298476165074504
# Finish 269 epoch(es)
# step 270 - loss 18.87185287475586 - moving ave loss 20.15581383604264
# Finish 270 epoch(es)
# step 271 - loss 18.735898971557617 - moving ave loss 20.013822349594136
# Finish 271 epoch(es)
# step 272 - loss 18.64483642578125 - moving ave loss 19.87692375721285
# Finish 272 epoch(es)
# step 273 - loss 18.77264404296875 - moving ave loss 19.76649578578844
# Finish 273 epoch(es)
# step 274 - loss 20.112186431884766 - moving ave loss 19.801064850398074
# Finish 274 epoch(es)
# step 275 - loss 19.438161849975586 - moving ave loss 19.764774550355824
# Finish 275 epoch(es)
# step 276 - loss 18.36916160583496 - moving ave loss 19.625213255903738
# Finish 276 epoch(es)
# step 277 - loss 18.143705368041992 - moving ave loss 19.477062467117563
# Finish 277 epoch(es)
# step 278 - loss 18.0020751953125 - moving ave loss 19.329563739937054
# Finish 278 epoch(es)
# step 279 - loss 17.886587142944336 - moving ave loss 19.185266080237785
# Finish 279 epoch(es)
# step 280 - loss 17.561670303344727 - moving ave loss 19.02290650254848
# Finish 280 epoch(es)
# step 281 - loss 16.85696029663086 - moving ave loss 18.806311881956717
# Finish 281 epoch(es)
# step 282 - loss 17.759546279907227 - moving ave loss 18.701635321751766
# Finish 282 epoch(es)
# step 283 - loss 17.536916732788086 - moving ave loss 18.585163462855398
# Finish 283 epoch(es)
# step 284 - loss 17.47473907470703 - moving ave loss 18.47412102404056
# Checkpoint at step 284
# Finish 284 epoch(es)
# step 285 - loss 17.151968002319336 - moving ave loss 18.341905721868436
# Finish 285 epoch(es)
# step 286 - loss 16.7371826171875 - moving ave loss 18.181433411400345
# Finish 286 epoch(es)
# step 287 - loss 16.45026969909668 - moving ave loss 18.00831704016998
# Finish 287 epoch(es)
# step 288 - loss 16.72696876525879 - moving ave loss 17.880182212678864
# Finish 288 epoch(es)
# step 289 - loss 16.732973098754883 - moving ave loss 17.765461301286464
# Finish 289 epoch(es)
# step 290 - loss 16.657989501953125 - moving ave loss 17.65471412135313
# Finish 290 epoch(es)
# step 291 - loss 16.28129005432129 - moving ave loss 17.517371714649947
# Finish 291 epoch(es)
# step 292 - loss 16.60697364807129 - moving ave loss 17.426331907992083
# Finish 292 epoch(es)
# step 293 - loss 16.251283645629883 - moving ave loss 17.308827081755865
# Finish 293 epoch(es)
# step 294 - loss 16.459426879882812 - moving ave loss 17.22388706156856
# Finish 294 epoch(es)
# step 295 - loss 16.33929443359375 - moving ave loss 17.13542779877108
# Finish 295 epoch(es)
# step 296 - loss 15.858819007873535 - moving ave loss 17.007766919681327
# Finish 296 epoch(es)
# step 297 - loss 16.792858123779297 - moving ave loss 16.986276040091123
# Finish 297 epoch(es)
# step 298 - loss 15.90451717376709 - moving ave loss 16.87810015345872
# Finish 298 epoch(es)
# step 299 - loss 15.93238639831543 - moving ave loss 16.783528777944394
# Finish 299 epoch(es)
# step 300 - loss 15.08010196685791 - moving ave loss 16.613186096835747
# Finish 300 epoch(es)
# step 301 - loss 15.27912425994873 - moving ave loss 16.479779913147045
# Finish 301 epoch(es)
# step 302 - loss 16.267244338989258 - moving ave loss 16.458526355731266
# Finish 302 epoch(es)
# step 303 - loss 15.136354446411133 - moving ave loss 16.32630916479925
# Finish 303 epoch(es)
# step 304 - loss 14.949054718017578 - moving ave loss 16.188583720121084
# Finish 304 epoch(es)
# step 305 - loss 15.608335494995117 - moving ave loss 16.130558897608488
# Finish 305 epoch(es)
# step 306 - loss 15.760321617126465 - moving ave loss 16.093535169560283
# Finish 306 epoch(es)
# step 307 - loss 14.582311630249023 - moving ave loss 15.942412815629158
# Finish 307 epoch(es)
# step 308 - loss 14.564302444458008 - moving ave loss 15.804601778512044
# Finish 308 epoch(es)
# step 309 - loss 14.694398880004883 - moving ave loss 15.693581488661328
# Finish 309 epoch(es)
# step 310 - loss 14.552210807800293 - moving ave loss 15.579444420575225
# Finish 310 epoch(es)
# step 311 - loss 14.30579662322998 - moving ave loss 15.4520796408407
# Finish 311 epoch(es)
# step 312 - loss 14.331365585327148 - moving ave loss 15.340008235289346
# Finish 312 epoch(es)
# step 313 - loss 14.894569396972656 - moving ave loss 15.295464351457678
# Finish 313 epoch(es)
# step 314 - loss 14.249505043029785 - moving ave loss 15.190868420614889
# Finish 314 epoch(es)
# step 315 - loss 14.0531005859375 - moving ave loss 15.07709163714715
# Finish 315 epoch(es)
# step 316 - loss 14.43297004699707 - moving ave loss 15.012679478132142
# Finish 316 epoch(es)
# step 317 - loss 15.256800651550293 - moving ave loss 15.037091595473958
# Finish 317 epoch(es)
# step 318 - loss 13.963005065917969 - moving ave loss 14.929682942518358
# Finish 318 epoch(es)
# step 319 - loss 16.67286491394043 - moving ave loss 15.104001139660566
# Finish 319 epoch(es)
# step 320 - loss 14.847817420959473 - moving ave loss 15.078382767790456
# Finish 320 epoch(es)
# step 321 - loss 13.426912307739258 - moving ave loss 14.913235721785338
# Finish 321 epoch(es)
# step 322 - loss 14.159589767456055 - moving ave loss 14.83787112635241
# Finish 322 epoch(es)
# step 323 - loss 13.560029983520508 - moving ave loss 14.71008701206922
# Finish 323 epoch(es)
# step 324 - loss 13.177201271057129 - moving ave loss 14.556798437968013
# Finish 324 epoch(es)
# step 325 - loss 13.804373741149902 - moving ave loss 14.481555968286202
# Finish 325 epoch(es)
# step 326 - loss 13.073211669921875 - moving ave loss 14.340721538449769
# Finish 326 epoch(es)
# step 327 - loss 13.02758502960205 - moving ave loss 14.209407887564998
# Finish 327 epoch(es)
# step 328 - loss 12.9988374710083 - moving ave loss 14.088350845909329
# Finish 328 epoch(es)
# step 329 - loss 13.103818893432617 - moving ave loss 13.989897650661657
# Finish 329 epoch(es)
# step 330 - loss 12.877816200256348 - moving ave loss 13.878689505621127
# Finish 330 epoch(es)
# step 331 - loss 13.029065132141113 - moving ave loss 13.793727068273126
# Finish 331 epoch(es)
# step 332 - loss 12.793985366821289 - moving ave loss 13.693752898127942
# Finish 332 epoch(es)
# step 333 - loss 13.243608474731445 - moving ave loss 13.648738455788292
# Finish 333 epoch(es)
# step 334 - loss 12.563578605651855 - moving ave loss 13.540222470774648
# Finish 334 epoch(es)
# step 335 - loss 12.63332462310791 - moving ave loss 13.449532686007974
# Finish 335 epoch(es)
# step 336 - loss 13.656754493713379 - moving ave loss 13.470254866778514
# Finish 336 epoch(es)
# step 337 - loss 12.26872444152832 - moving ave loss 13.350101824253496
# Finish 337 epoch(es)
# step 338 - loss 12.270003318786621 - moving ave loss 13.242091973706808
# Finish 338 epoch(es)
# step 339 - loss 11.707601547241211 - moving ave loss 13.088642931060248
# Finish 339 epoch(es)
# step 340 - loss 12.294828414916992 - moving ave loss 13.009261479445922
# Finish 340 epoch(es)
# step 341 - loss 12.27069091796875 - moving ave loss 12.935404423298206
# Finish 341 epoch(es)
# step 342 - loss 11.844883918762207 - moving ave loss 12.826352372844605
# Finish 342 epoch(es)
# step 343 - loss 11.688193321228027 - moving ave loss 12.712536467682948
# Finish 343 epoch(es)
# step 344 - loss 13.477571487426758 - moving ave loss 12.789039969657331
# Finish 344 epoch(es)
# step 345 - loss 11.627191543579102 - moving ave loss 12.672855127049509
# Finish 345 epoch(es)
# step 346 - loss 11.637290954589844 - moving ave loss 12.569298709803544
# Finish 346 epoch(es)
# step 347 - loss 14.02722454071045 - moving ave loss 12.715091292894234
# Finish 347 epoch(es)
# step 348 - loss 11.848649024963379 - moving ave loss 12.628447066101149
# Finish 348 epoch(es)
# step 349 - loss 12.031214714050293 - moving ave loss 12.568723830896065
# Finish 349 epoch(es)
# step 350 - loss 11.696015357971191 - moving ave loss 12.481452983603578
# Finish 350 epoch(es)
# step 351 - loss 11.442123413085938 - moving ave loss 12.377520026551814
# Finish 351 epoch(es)
# step 352 - loss 11.314032554626465 - moving ave loss 12.27117127935928
# Finish 352 epoch(es)
# step 353 - loss 12.829367637634277 - moving ave loss 12.32699091518678
# Finish 353 epoch(es)
# step 354 - loss 12.060453414916992 - moving ave loss 12.300337165159803
# Finish 354 epoch(es)
# step 355 - loss 11.342622756958008 - moving ave loss 12.204565724339624
# Finish 355 epoch(es)
# step 356 - loss 11.97714900970459 - moving ave loss 12.18182405287612
# Finish 356 epoch(es)
# step 357 - loss 10.99448299407959 - moving ave loss 12.063089946996467
# Finish 357 epoch(es)
# step 358 - loss 10.89908504486084 - moving ave loss 11.946689456782904
# Finish 358 epoch(es)
# step 359 - loss 12.260151863098145 - moving ave loss 11.978035697414429
# Finish 359 epoch(es)
# step 360 - loss 10.571730613708496 - moving ave loss 11.837405189043837
# Finish 360 epoch(es)
# step 361 - loss 10.974832534790039 - moving ave loss 11.751147923618458
# Finish 361 epoch(es)
# step 362 - loss 10.37960147857666 - moving ave loss 11.613993279114277
# Finish 362 epoch(es)
# step 363 - loss 10.511262893676758 - moving ave loss 11.503720240570527
# Finish 363 epoch(es)
# step 364 - loss 10.569523811340332 - moving ave loss 11.410300597647508
# Finish 364 epoch(es)
# step 365 - loss 10.505223274230957 - moving ave loss 11.319792865305853
# Finish 365 epoch(es)
# step 366 - loss 10.514374732971191 - moving ave loss 11.239251052072387
# Finish 366 epoch(es)
# step 367 - loss 10.30580997467041 - moving ave loss 11.14590694433219
# Finish 367 epoch(es)
# step 368 - loss 10.36817741394043 - moving ave loss 11.068133991293013
# Finish 368 epoch(es)
# step 369 - loss 10.237021446228027 - moving ave loss 10.985022736786515
# Finish 369 epoch(es)
# step 370 - loss 9.960837364196777 - moving ave loss 10.882604199527542
# Finish 370 epoch(es)
# step 371 - loss 10.19219970703125 - moving ave loss 10.813563750277913
# Finish 371 epoch(es)
# step 372 - loss 11.074319839477539 - moving ave loss 10.839639359197875
# Finish 372 epoch(es)
# step 373 - loss 10.112762451171875 - moving ave loss 10.766951668395276
# Finish 373 epoch(es)
# step 374 - loss 10.071784019470215 - moving ave loss 10.697434903502769
# Finish 374 epoch(es)
# step 375 - loss 10.039849281311035 - moving ave loss 10.631676341283596
# Finish 375 epoch(es)
# step 376 - loss 10.449976921081543 - moving ave loss 10.613506399263391
# Finish 376 epoch(es)
# step 377 - loss 9.680825233459473 - moving ave loss 10.520238282683
# Finish 377 epoch(es)
# step 378 - loss 9.233222961425781 - moving ave loss 10.391536750557277
# Finish 378 epoch(es)
# step 379 - loss 9.815324783325195 - moving ave loss 10.33391555383407
# Finish 379 epoch(es)
# step 380 - loss 10.613005638122559 - moving ave loss 10.36182456226292
# Finish 380 epoch(es)
# step 381 - loss 9.450199127197266 - moving ave loss 10.270662018756353
# Finish 381 epoch(es)
# step 382 - loss 10.293476104736328 - moving ave loss 10.272943427354349
# Finish 382 epoch(es)
# step 383 - loss 9.221028327941895 - moving ave loss 10.167751917413105
# Finish 383 epoch(es)
# step 384 - loss 10.132902145385742 - moving ave loss 10.16426694021037
# Finish 384 epoch(es)
# step 385 - loss 9.294242858886719 - moving ave loss 10.077264532078004
# Finish 385 epoch(es)
# step 386 - loss 10.143967628479004 - moving ave loss 10.083934841718104
# Finish 386 epoch(es)
# step 387 - loss 9.243573188781738 - moving ave loss 9.999898676424468
# Finish 387 epoch(es)
# step 388 - loss 9.311713218688965 - moving ave loss 9.931080130650919
# Finish 388 epoch(es)
# step 389 - loss 9.793444633483887 - moving ave loss 9.917316580934216
# Finish 389 epoch(es)
# step 390 - loss 8.795825958251953 - moving ave loss 9.80516751866599
# Finish 390 epoch(es)
# step 391 - loss 9.313185691833496 - moving ave loss 9.75596933598274
# Finish 391 epoch(es)
# step 392 - loss 8.626433372497559 - moving ave loss 9.643015739634222
# Finish 392 epoch(es)
# step 393 - loss 8.98654556274414 - moving ave loss 9.577368721945215
# Finish 393 epoch(es)
# step 394 - loss 8.644186973571777 - moving ave loss 9.48405054710787
# Finish 394 epoch(es)
# step 395 - loss 9.189229011535645 - moving ave loss 9.454568393550648
# Finish 395 epoch(es)
# step 396 - loss 9.080527305603027 - moving ave loss 9.417164284755888
# Finish 396 epoch(es)
# step 397 - loss 8.283995628356934 - moving ave loss 9.303847419115993
# Finish 397 epoch(es)
# step 398 - loss 9.033090591430664 - moving ave loss 9.27677173634746
# Finish 398 epoch(es)
# step 399 - loss 8.19996166229248 - moving ave loss 9.169090728941963
# Finish 399 epoch(es)
# step 400 - loss 8.577425003051758 - moving ave loss 9.109924156352943
# Finish 400 epoch(es)
# step 401 - loss 9.439310073852539 - moving ave loss 9.142862748102903
# Finish 401 epoch(es)
# step 402 - loss 8.67656421661377 - moving ave loss 9.096232894953989
# Finish 402 epoch(es)
# step 403 - loss 8.461348533630371 - moving ave loss 9.032744458821627
# Finish 403 epoch(es)
# step 404 - loss 8.432580947875977 - moving ave loss 8.972728107727061
# Finish 404 epoch(es)
# step 405 - loss 8.19140911102295 - moving ave loss 8.894596208056651
# Finish 405 epoch(es)
# step 406 - loss 8.149847030639648 - moving ave loss 8.820121290314951
# Finish 406 epoch(es)
# step 407 - loss 8.043213844299316 - moving ave loss 8.742430545713388
# Finish 407 epoch(es)
# step 408 - loss 8.14863395690918 - moving ave loss 8.683050886832968
# Finish 408 epoch(es)
# step 409 - loss 9.764849662780762 - moving ave loss 8.791230764427747
# Finish 409 epoch(es)
# step 410 - loss 9.170062065124512 - moving ave loss 8.829113894497423
# Finish 410 epoch(es)
# step 411 - loss 7.954920768737793 - moving ave loss 8.741694581921461
# Finish 411 epoch(es)
# step 412 - loss 8.118139266967773 - moving ave loss 8.679339050426092
# Finish 412 epoch(es)
# step 413 - loss 8.513294219970703 - moving ave loss 8.662734567380554
# Finish 413 epoch(es)
# step 414 - loss 8.636686325073242 - moving ave loss 8.660129743149822
# Finish 414 epoch(es)
# step 415 - loss 7.891748905181885 - moving ave loss 8.583291659353028
# Finish 415 epoch(es)
# step 416 - loss 8.473786354064941 - moving ave loss 8.57234112882422
# Finish 416 epoch(es)
# step 417 - loss 7.624393939971924 - moving ave loss 8.477546409938991
# Finish 417 epoch(es)
# step 418 - loss 7.8245086669921875 - moving ave loss 8.412242635644311
# Finish 418 epoch(es)
# step 419 - loss 7.7895989418029785 - moving ave loss 8.349978266260178
# Finish 419 epoch(es)
# step 420 - loss 8.600013732910156 - moving ave loss 8.374981812925176
# Finish 420 epoch(es)
# step 421 - loss 7.478480815887451 - moving ave loss 8.285331713221405
# Finish 421 epoch(es)
# step 422 - loss 7.253414630889893 - moving ave loss 8.182140004988254
# Finish 422 epoch(es)
# step 423 - loss 7.258205890655518 - moving ave loss 8.089746593554981
# Finish 423 epoch(es)
# step 424 - loss 7.63615083694458 - moving ave loss 8.044387017893941
# Finish 424 epoch(es)
# step 425 - loss 7.2439656257629395 - moving ave loss 7.964344878680841
# Finish 425 epoch(es)
# step 426 - loss 8.10318374633789 - moving ave loss 7.978228765446546
# Checkpoint at step 426
# Finish 426 epoch(es)
# step 427 - loss 7.264316082000732 - moving ave loss 7.906837497101964
# Finish 427 epoch(es)
# step 428 - loss 7.5076117515563965 - moving ave loss 7.866914922547408
# Finish 428 epoch(es)
# step 429 - loss 7.391012191772461 - moving ave loss 7.819324649469913
# Finish 429 epoch(es)
# step 430 - loss 6.930790901184082 - moving ave loss 7.73047127464133
# Finish 430 epoch(es)
# step 431 - loss 8.284137725830078 - moving ave loss 7.785837919760205
# Finish 431 epoch(es)
# step 432 - loss 7.008152484893799 - moving ave loss 7.708069376273564
# Finish 432 epoch(es)
# step 433 - loss 7.606770992279053 - moving ave loss 7.697939537874113
# Finish 433 epoch(es)
# step 434 - loss 7.580236911773682 - moving ave loss 7.686169275264071
# Finish 434 epoch(es)
# step 435 - loss 7.298081398010254 - moving ave loss 7.647360487538689
# Finish 435 epoch(es)
# step 436 - loss 8.978714942932129 - moving ave loss 7.780495933078034
# Finish 436 epoch(es)
# step 437 - loss 6.849538326263428 - moving ave loss 7.687400172396574
# Finish 437 epoch(es)
# step 438 - loss 6.845577716827393 - moving ave loss 7.6032179268396565
# Finish 438 epoch(es)
# step 439 - loss 7.0855841636657715 - moving ave loss 7.551454550522267
# Finish 439 epoch(es)
# step 440 - loss 7.787363529205322 - moving ave loss 7.575045448390573
# Finish 440 epoch(es)
# step 441 - loss 6.807137489318848 - moving ave loss 7.4982546524834
# Finish 441 epoch(es)
# step 442 - loss 7.403780460357666 - moving ave loss 7.488807233270827
# Finish 442 epoch(es)
# step 443 - loss 6.5832200050354 - moving ave loss 7.398248510447285
# Finish 443 epoch(es)
# step 444 - loss 6.613460540771484 - moving ave loss 7.319769713479705
# Finish 444 epoch(es)
# step 445 - loss 6.429569721221924 - moving ave loss 7.2307497142539265
# Finish 445 epoch(es)
# step 446 - loss 6.353180885314941 - moving ave loss 7.142992831360028
# Finish 446 epoch(es)
# step 447 - loss 6.386795997619629 - moving ave loss 7.067373147985988
# Finish 447 epoch(es)
# step 448 - loss 6.283133029937744 - moving ave loss 6.988949136181164
# Finish 448 epoch(es)
# step 449 - loss 7.358922481536865 - moving ave loss 7.025946470716734
# Finish 449 epoch(es)
# step 450 - loss 6.518677234649658 - moving ave loss 6.975219547110028
# Finish 450 epoch(es)
# step 451 - loss 7.012569904327393 - moving ave loss 6.978954582831764
# Finish 451 epoch(es)
# step 452 - loss 6.19670295715332 - moving ave loss 6.90072942026392
# Finish 452 epoch(es)
# step 453 - loss 6.3629961013793945 - moving ave loss 6.846956088375467
# Finish 453 epoch(es)
# step 454 - loss 6.361351490020752 - moving ave loss 6.798395628539996
# Finish 454 epoch(es)
# step 455 - loss 6.2084221839904785 - moving ave loss 6.739398284085045
# Finish 455 epoch(es)
# step 456 - loss 6.1751708984375 - moving ave loss 6.682975545520291
# Finish 456 epoch(es)
# step 457 - loss 6.244112968444824 - moving ave loss 6.6390892878127445
# Finish 457 epoch(es)
# step 458 - loss 6.046082973480225 - moving ave loss 6.579788656379493
# Finish 458 epoch(es)
# step 459 - loss 6.156404972076416 - moving ave loss 6.537450287949186
# Finish 459 epoch(es)
# step 460 - loss 6.096563816070557 - moving ave loss 6.493361640761323
# Finish 460 epoch(es)
# step 461 - loss 6.72626256942749 - moving ave loss 6.51665173362794
# Finish 461 epoch(es)
# step 462 - loss 5.868431091308594 - moving ave loss 6.451829669396005
# Finish 462 epoch(es)
# step 463 - loss 5.860093116760254 - moving ave loss 6.39265601413243
# Finish 463 epoch(es)
# step 464 - loss 6.12006139755249 - moving ave loss 6.3653965524744365
# Finish 464 epoch(es)
# step 465 - loss 6.2160162925720215 - moving ave loss 6.350458526484195
# Finish 465 epoch(es)
# step 466 - loss 5.9272003173828125 - moving ave loss 6.308132705574057
# Finish 466 epoch(es)
# step 467 - loss 6.030684471130371 - moving ave loss 6.280387882129688
# Finish 467 epoch(es)
# step 468 - loss 5.6647114753723145 - moving ave loss 6.21882024145395
# Finish 468 epoch(es)
# step 469 - loss 5.6013007164001465 - moving ave loss 6.15706828894857
# Finish 469 epoch(es)
# step 470 - loss 7.275921821594238 - moving ave loss 6.268953642213137
# Finish 470 epoch(es)
# ...
# step 829 - loss 1.5537331104278564 - moving ave loss 1.4570398011742272
# Finish 829 epoch(es)
# step 830 - loss 2.3518881797790527 - moving ave loss 1.5465246390347098
# Finish 830 epoch(es)
# step 831 - loss 1.351410150527954 - moving ave loss 1.5270131901840343
# Finish 831 epoch(es)
# step 832 - loss 1.2687519788742065 - moving ave loss 1.5011870690530515
# Finish 832 epoch(es)
# step 833 - loss 1.274279236793518 - moving ave loss 1.4784962858270982
# Finish 833 epoch(es)
# step 834 - loss 1.1736406087875366 - moving ave loss 1.448010718123142
# Finish 834 epoch(es)
# step 835 - loss 1.4646258354187012 - moving ave loss 1.4496722298526978
# Finish 835 epoch(es)
# step 836 - loss 2.0583410263061523 - moving ave loss 1.5105391094980434
# Finish 836 epoch(es)
# step 837 - loss 1.3669102191925049 - moving ave loss 1.4961762204674895
# Finish 837 epoch(es)
# step 838 - loss 1.4358632564544678 - moving ave loss 1.4901449240661875
# Finish 838 epoch(es)
# step 839 - loss 0.9995604753494263 - moving ave loss 1.4410864791945113
# Finish 839 epoch(es)
# step 840 - loss 1.533259630203247 - moving ave loss 1.450303794295385
# Finish 840 epoch(es)
# step 841 - loss 1.316153883934021 - moving ave loss 1.4368888032592486
# Finish 841 epoch(es)
# step 842 - loss 1.269006609916687 - moving ave loss 1.4201005839249925
# Finish 842 epoch(es)
# step 843 - loss 1.1825273036956787 - moving ave loss 1.3963432559020612
# Finish 843 epoch(es)
# step 844 - loss 1.3233269453048706 - moving ave loss 1.389041624842342
# Finish 844 epoch(es)
# step 845 - loss 1.538267970085144 - moving ave loss 1.4039642593666222
# Finish 845 epoch(es)
# step 846 - loss 1.189902663230896 - moving ave loss 1.3825580997530496
# Finish 846 epoch(es)
# step 847 - loss 1.2483619451522827 - moving ave loss 1.369138484292973
# Finish 847 epoch(es)
# step 848 - loss 1.0096569061279297 - moving ave loss 1.3331903264764686
# Finish 848 epoch(es)
# step 849 - loss 1.7530765533447266 - moving ave loss 1.3751789491632946
# Finish 849 epoch(es)
# step 850 - loss 1.4250766038894653 - moving ave loss 1.3801687146359118
# Finish 850 epoch(es)
# step 851 - loss 1.2440158128738403 - moving ave loss 1.3665534244597046
# Finish 851 epoch(es)
# step 852 - loss 1.36702561378479 - moving ave loss 1.366600643392213
# Checkpoint at step 852
# Finish 852 epoch(es)
# step 853 - loss 1.994435429573059 - moving ave loss 1.4293841220102976
# Finish 853 epoch(es)
# step 854 - loss 1.2223501205444336 - moving ave loss 1.4086807218637112
# Finish 854 epoch(es)
# step 855 - loss 1.0905488729476929 - moving ave loss 1.3768675369721093
# Finish 855 epoch(es)
# step 856 - loss 1.4940611124038696 - moving ave loss 1.3885868945152855
# Finish 856 epoch(es)
# step 857 - loss 1.3212050199508667 - moving ave loss 1.3818487070588437
# Finish 857 epoch(es)
# step 858 - loss 1.1356780529022217 - moving ave loss 1.3572316416431816
# Finish 858 epoch(es)
# step 859 - loss 1.009749412536621 - moving ave loss 1.3224834187325254
# Finish 859 epoch(es)
# step 860 - loss 1.4051440954208374 - moving ave loss 1.3307494864013567
# Finish 860 epoch(es)
# step 861 - loss 1.3972328901290894 - moving ave loss 1.33739782677413
# Finish 861 epoch(es)
# step 862 - loss 1.3224800825119019 - moving ave loss 1.3359060523479072
# Finish 862 epoch(es)
# step 863 - loss 1.0940223932266235 - moving ave loss 1.311717686435779
# Finish 863 epoch(es)
# step 864 - loss 1.969620943069458 - moving ave loss 1.377508012099147
# Finish 864 epoch(es)
# step 865 - loss 1.1484159231185913 - moving ave loss 1.3545988032010914
# Finish 865 epoch(es)
# step 866 - loss 1.3196386098861694 - moving ave loss 1.3511027838695993
# Finish 866 epoch(es)
# step 867 - loss 1.051989197731018 - moving ave loss 1.321191425255741
# Finish 867 epoch(es)
# step 868 - loss 0.8480169177055359 - moving ave loss 1.2738739745007206
# Finish 868 epoch(es)
# step 869 - loss 0.8840535283088684 - moving ave loss 1.2348919298815353
# Finish 869 epoch(es)
# step 870 - loss 1.579845666885376 - moving ave loss 1.2693873035819194
# Finish 870 epoch(es)
# step 871 - loss 1.5178759098052979 - moving ave loss 1.2942361642042572
# Finish 871 epoch(es)
# step 872 - loss 1.1985628604888916 - moving ave loss 1.2846688338327208
# Finish 872 epoch(es)
# step 873 - loss 1.0972377061843872 - moving ave loss 1.2659257210678874
# Finish 873 epoch(es)
# step 874 - loss 1.0060118436813354 - moving ave loss 1.2399343333292323
# Finish 874 epoch(es)
# step 875 - loss 1.6413782835006714 - moving ave loss 1.2800787283463764
# Finish 875 epoch(es)
# step 876 - loss 1.5510241985321045 - moving ave loss 1.3071732753649492
# Finish 876 epoch(es)
# step 877 - loss 1.0316565036773682 - moving ave loss 1.2796215981961911
# Finish 877 epoch(es)
# step 878 - loss 1.5203216075897217 - moving ave loss 1.3036915991355444
# Finish 878 epoch(es)
# step 879 - loss 0.8246089220046997 - moving ave loss 1.25578333142246
# Finish 879 epoch(es)
# step 880 - loss 1.0128042697906494 - moving ave loss 1.231485425259279
# Finish 880 epoch(es)
# step 881 - loss 1.5622748136520386 - moving ave loss 1.264564364098555
# Finish 881 epoch(es)
# step 882 - loss 2.434075117111206 - moving ave loss 1.3815154393998204
# Finish 882 epoch(es)
# step 883 - loss 0.7797999382019043 - moving ave loss 1.3213438892800287
# Finish 883 epoch(es)
# step 884 - loss 1.5136419534683228 - moving ave loss 1.340573695698858
# Finish 884 epoch(es)
# step 885 - loss 0.8355574011802673 - moving ave loss 1.290072066246999
# Finish 885 epoch(es)
# step 886 - loss 2.1853585243225098 - moving ave loss 1.3796007120545501
# Finish 886 epoch(es)
# step 887 - loss 1.2312710285186768 - moving ave loss 1.3647677437009629
# Finish 887 epoch(es)
# step 888 - loss 1.1157914400100708 - moving ave loss 1.3398701133318736
# Finish 888 epoch(es)
# step 889 - loss 1.1459990739822388 - moving ave loss 1.32048300939691
# Finish 889 epoch(es)
# step 890 - loss 1.0716034173965454 - moving ave loss 1.2955950501968736
# Finish 890 epoch(es)
# step 891 - loss 1.5376701354980469 - moving ave loss 1.319802558726991
# Finish 891 epoch(es)
# step 892 - loss 1.6570173501968384 - moving ave loss 1.353524037873976
# Finish 892 epoch(es)
# step 893 - loss 1.0883328914642334 - moving ave loss 1.3270049232330017
# Finish 893 epoch(es)
# step 894 - loss 1.236504316329956 - moving ave loss 1.3179548625426971
# Finish 894 epoch(es)
# step 895 - loss 1.1648682355880737 - moving ave loss 1.302646199847235
# Finish 895 epoch(es)
# step 896 - loss 1.0179674625396729 - moving ave loss 1.2741783261164787
# Finish 896 epoch(es)
# step 897 - loss 1.7276513576507568 - moving ave loss 1.3195256292699067
# Finish 897 epoch(es)
# step 898 - loss 1.0932703018188477 - moving ave loss 1.2969000965248008
# Finish 898 epoch(es)
# step 899 - loss 1.1843044757843018 - moving ave loss 1.2856405344507509
# Finish 899 epoch(es)
# step 900 - loss 1.027146816253662 - moving ave loss 1.2597911626310418
# Finish 900 epoch(es)
# step 901 - loss 1.6940621137619019 - moving ave loss 1.303218257744128
# Finish 901 epoch(es)
# step 902 - loss 1.063812255859375 - moving ave loss 1.2792776575556528
# Finish 902 epoch(es)
# step 903 - loss 0.7542052865028381 - moving ave loss 1.2267704204503713
# Finish 903 epoch(es)
# step 904 - loss 1.0079190731048584 - moving ave loss 1.20488528571582
# Finish 904 epoch(es)
# step 905 - loss 1.525017261505127 - moving ave loss 1.236898483294751
# Finish 905 epoch(es)
# step 906 - loss 0.9535826444625854 - moving ave loss 1.2085668994115344
# Finish 906 epoch(es)
# step 907 - loss 1.0275486707687378 - moving ave loss 1.1904650765472549
# Finish 907 epoch(es)
# step 908 - loss 0.9468735456466675 - moving ave loss 1.1661059234571962
# Finish 908 epoch(es)
# step 909 - loss 1.5986186265945435 - moving ave loss 1.2093571937709309
# Finish 909 epoch(es)
# step 910 - loss 0.7212753891944885 - moving ave loss 1.1605490133132867
# Finish 910 epoch(es)
# step 911 - loss 2.041228771209717 - moving ave loss 1.24861698910293
# Finish 911 epoch(es)
# step 912 - loss 0.768667995929718 - moving ave loss 1.2006220897856088
# Finish 912 epoch(es)
# step 913 - loss 1.2352403402328491 - moving ave loss 1.2040839148303328
# Finish 913 epoch(es)
# step 914 - loss 1.0988295078277588 - moving ave loss 1.1935584741300755
# Finish 914 epoch(es)
# step 915 - loss 0.9257926344871521 - moving ave loss 1.1667818901657834
# Finish 915 epoch(es)
# step 916 - loss 0.8622477650642395 - moving ave loss 1.136328477655629
# Finish 916 epoch(es)
# step 917 - loss 1.0219889879226685 - moving ave loss 1.124894528682333
# Finish 917 epoch(es)
# step 918 - loss 1.2979158163070679 - moving ave loss 1.1421966574448066
# Finish 918 epoch(es)
# step 919 - loss 0.963715672492981 - moving ave loss 1.124348558949624
# Finish 919 epoch(es)
# step 920 - loss 2.569875478744507 - moving ave loss 1.2689012509291124
# Finish 920 epoch(es)
# step 921 - loss 1.1197134256362915 - moving ave loss 1.2539824683998302
# Finish 921 epoch(es)
# step 922 - loss 1.3332279920578003 - moving ave loss 1.261907020765627
# Finish 922 epoch(es)
# step 923 - loss 1.0848108530044556 - moving ave loss 1.24419740398951
# Finish 923 epoch(es)
# step 924 - loss 1.6564363241195679 - moving ave loss 1.285421296002516
# Finish 924 epoch(es)
# step 925 - loss 0.9004952311515808 - moving ave loss 1.2469286895174225
# Finish 925 epoch(es)
# step 926 - loss 0.9329638481140137 - moving ave loss 1.2155322053770818
# Finish 926 epoch(es)
# step 927 - loss 1.0078755617141724 - moving ave loss 1.194766541010791
# Finish 927 epoch(es)
# step 928 - loss 0.8253094553947449 - moving ave loss 1.1578208324491865
# Finish 928 epoch(es)
# step 929 - loss 1.207690954208374 - moving ave loss 1.1628078446251053
# Finish 929 epoch(es)
# step 930 - loss 1.04109787940979 - moving ave loss 1.1506368481035738
# Finish 930 epoch(es)
# step 931 - loss 1.4057629108428955 - moving ave loss 1.176149454377506
# Finish 931 epoch(es)
# step 932 - loss 0.9794723987579346 - moving ave loss 1.1564817488155488
# Finish 932 epoch(es)
# step 933 - loss 0.9124731421470642 - moving ave loss 1.1320808881487003
# Finish 933 epoch(es)
# step 934 - loss 1.1126855611801147 - moving ave loss 1.1301413554518418
# Finish 934 epoch(es)
# step 935 - loss 1.1993474960327148 - moving ave loss 1.137061969509929
# Finish 935 epoch(es)
# step 936 - loss 1.0964411497116089 - moving ave loss 1.132999887530097
# Finish 936 epoch(es)
# step 937 - loss 1.2858818769454956 - moving ave loss 1.148288086471637
# Finish 937 epoch(es)
# step 938 - loss 1.113523244857788 - moving ave loss 1.1448116023102521
# Finish 938 epoch(es)
# step 939 - loss 0.8642948269844055 - moving ave loss 1.1167599247776676
# Finish 939 epoch(es)
# step 940 - loss 0.7105981111526489 - moving ave loss 1.0761437434151657
# Finish 940 epoch(es)
# step 941 - loss 1.0245074033737183 - moving ave loss 1.070980109411021
# Finish 941 epoch(es)
# step 942 - loss 1.0440999269485474 - moving ave loss 1.0682920911647735
# Finish 942 epoch(es)
# step 943 - loss 1.9714001417160034 - moving ave loss 1.1586028962198966
# Finish 943 epoch(es)
# step 944 - loss 1.3156362771987915 - moving ave loss 1.1743062343177861
# Finish 944 epoch(es)
# step 945 - loss 1.257407307624817 - moving ave loss 1.1826163416484892
# Finish 945 epoch(es)
# step 946 - loss 0.9614323973655701 - moving ave loss 1.1604979472201973
# Finish 946 epoch(es)
# step 947 - loss 0.826943039894104 - moving ave loss 1.127142456487588
# Finish 947 epoch(es)
# step 948 - loss 0.9781392216682434 - moving ave loss 1.1122421330056536
# Finish 948 epoch(es)
# step 949 - loss 1.3933947086334229 - moving ave loss 1.1403573905684303
# Finish 949 epoch(es)
# step 950 - loss 1.2997289896011353 - moving ave loss 1.1562945504717008
# Finish 950 epoch(es)
# step 951 - loss 1.1388499736785889 - moving ave loss 1.1545500927923895
# Finish 951 epoch(es)
# step 952 - loss 1.239113688468933 - moving ave loss 1.1630064523600439
# Finish 952 epoch(es)
# step 953 - loss 1.1359751224517822 - moving ave loss 1.1603033193692178
# Finish 953 epoch(es)
# step 954 - loss 1.073553204536438 - moving ave loss 1.1516283078859397
# Finish 954 epoch(es)
# step 955 - loss 1.1938250064849854 - moving ave loss 1.1558479777458444
# Finish 955 epoch(es)
# step 956 - loss 0.9294105768203735 - moving ave loss 1.1332042376532974
# Finish 956 epoch(es)
# step 957 - loss 1.1197073459625244 - moving ave loss 1.13185454848422
# Finish 957 epoch(es)
# step 958 - loss 0.9735487699508667 - moving ave loss 1.1160239706308848
# Finish 958 epoch(es)
# step 959 - loss 1.0237994194030762 - moving ave loss 1.106801515508104
# Finish 959 epoch(es)
# step 960 - loss 0.9847796559333801 - moving ave loss 1.0945993295506316
# Finish 960 epoch(es)
# step 961 - loss 1.5285711288452148 - moving ave loss 1.13799650948009
# Finish 961 epoch(es)
# step 962 - loss 1.1939977407455444 - moving ave loss 1.1435966326066354
# Finish 962 epoch(es)
# step 963 - loss 1.0480901002883911 - moving ave loss 1.1340459793748108
# Finish 963 epoch(es)
# step 964 - loss 0.7025413513183594 - moving ave loss 1.0908955165691656
# Finish 964 epoch(es)
# step 965 - loss 1.2849464416503906 - moving ave loss 1.110300609077288
# Finish 965 epoch(es)
# step 966 - loss 0.9479018449783325 - moving ave loss 1.0940607326673923
# Finish 966 epoch(es)
# step 967 - loss 1.3521323204040527 - moving ave loss 1.1198678914410585
# Finish 967 epoch(es)
# step 968 - loss 0.7816113233566284 - moving ave loss 1.0860422346326155
# Finish 968 epoch(es)
# step 969 - loss 1.0965626239776611 - moving ave loss 1.08709427356712
# Finish 969 epoch(es)
# step 970 - loss 1.4224523305892944 - moving ave loss 1.1206300792693376
# Finish 970 epoch(es)
# step 971 - loss 1.0225359201431274 - moving ave loss 1.1108206633567166
# Finish 971 epoch(es)
# step 972 - loss 1.526674509048462 - moving ave loss 1.152406047925891
# Finish 972 epoch(es)
# step 973 - loss 1.3750369548797607 - moving ave loss 1.174669138621278
# Finish 973 epoch(es)
# step 974 - loss 0.8052307367324829 - moving ave loss 1.1377252984323984
# Finish 974 epoch(es)
# step 975 - loss 0.9159291386604309 - moving ave loss 1.115545682455202
# Finish 975 epoch(es)
# step 976 - loss 1.0091032981872559 - moving ave loss 1.1049014440284073
# Finish 976 epoch(es)
# step 977 - loss 1.3318132162094116 - moving ave loss 1.1275926212465077
# Finish 977 epoch(es)
# step 978 - loss 0.9034990668296814 - moving ave loss 1.105183265804825
# Finish 978 epoch(es)
# step 979 - loss 1.0224000215530396 - moving ave loss 1.0969049413796466
# Finish 979 epoch(es)
# step 980 - loss 0.8339008092880249 - moving ave loss 1.0706045281704843
# Finish 980 epoch(es)
# step 981 - loss 1.0516396760940552 - moving ave loss 1.0687080429628415
# Finish 981 epoch(es)
# step 982 - loss 1.2085763216018677 - moving ave loss 1.082694870826744
# Finish 982 epoch(es)
# step 983 - loss 1.1566859483718872 - moving ave loss 1.0900939785812584
# Finish 983 epoch(es)
# step 984 - loss 0.8778141736984253 - moving ave loss 1.0688659980929751
# Finish 984 epoch(es)
# step 985 - loss 0.6643171310424805 - moving ave loss 1.0284111113879257
# Finish 985 epoch(es)
# step 986 - loss 1.980436086654663 - moving ave loss 1.1236136089145994
# Finish 986 epoch(es)
# step 987 - loss 1.0044485330581665 - moving ave loss 1.111697101328956
# Finish 987 epoch(es)
# step 988 - loss 0.5992139577865601 - moving ave loss 1.0604487869747163
# Finish 988 epoch(es)
# step 989 - loss 0.9983471035957336 - moving ave loss 1.054238618636818
# Finish 989 epoch(es)
# step 990 - loss 1.0297088623046875 - moving ave loss 1.051785643003605
# Finish 990 epoch(es)
# step 991 - loss 1.2245066165924072 - moving ave loss 1.0690577403624852
# Finish 991 epoch(es)
# step 992 - loss 1.0598560571670532 - moving ave loss 1.068137572042942
# Finish 992 epoch(es)
# step 993 - loss 2.37967848777771 - moving ave loss 1.1992916636164188
# Finish 993 epoch(es)
# step 994 - loss 1.5363985300064087 - moving ave loss 1.233002350255418
# Checkpoint at step 994
# Finish 994 epoch(es)
# step 995 - loss 1.1596266031265259 - moving ave loss 1.225664775542529
# Finish 995 epoch(es)
# step 996 - loss 1.1850234270095825 - moving ave loss 1.2216006406892344
# Finish 996 epoch(es)
# step 997 - loss 0.732909619808197 - moving ave loss 1.1727315386011308
# Finish 997 epoch(es)
# step 998 - loss 1.080655813217163 - moving ave loss 1.1635239660627341
# Finish 998 epoch(es)
# step 999 - loss 0.8653770685195923 - moving ave loss 1.13370927630842
# Finish 999 epoch(es)
# step 1000 - loss 1.1918554306030273 - moving ave loss 1.139523891737881
# Finish 1000 epoch(es)
# Checkpoint at step 1000
# Training finished, exit.
