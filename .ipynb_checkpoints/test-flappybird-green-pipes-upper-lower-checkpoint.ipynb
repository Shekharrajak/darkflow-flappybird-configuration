# %%
import cv2
from darkflow.net.build import TFNet
import matplotlib.pyplot as plt

#To show this as svg images
# %config InlineBackend.figure_format = 'svg'

# %%
options = {
    'model': 'cfg/tiny-yolo-voc-1c.cfg',
    'load': 1000,                            
    'threshold': 0.1,                       
                            
}

tfnet = TFNet(options)
# Out:
# Parsing cfg/tiny-yolo-voc-1c.cfg
# Loading None ...
# Finished in 0.00019121170043945312s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
# WARNING:tensorflow:From /home/shekharrajak/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
#        |        | input                            | (?, 416, 416, 3)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 16)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 16)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 32)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 52, 52, 64)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 26, 26, 128)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 26, 26, 256)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 13, 13, 256)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 512)
#  Load  |  Yep!  | maxp 2x2p0_1                     | (?, 13, 13, 512)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Init  |  Yep!  | conv 1x1p0_1    linear           | (?, 13, 13, 40)
# -------+--------+----------------------------------+---------------
# Running entirely on CPU
# Loading from ./ckpt/tiny-yolo-voc-1c-1000
# WARNING:tensorflow:From /home/shekharrajak/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./ckpt/tiny-yolo-voc-1c-1000
# Finished in 3.119295597076416s

# %%
# read the color image and covert to RGB

img = cv2.imread('new_model_data/images/3.jpg', cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# use YOLO to predict the image
result = tfnet.return_predict(img)

img.shape
# Out:
# (771, 1200, 3)

# %%
result
# Out:
# [{'label': 'flappybird',
#   'confidence': 0.16957073,
#   'topleft': {'x': 123, 'y': 406},
#   'bottomright': {'x': 203, 'y': 478}},
#  {'label': 'green-pipe-up',
#   'confidence': 0.3060803,
#   'topleft': {'x': 568, 'y': 37},
#   'bottomright': {'x': 648, 'y': 113}},
#  {'label': 'green-pipe-up',
#   'confidence': 0.48525736,
#   'topleft': {'x': 925, 'y': 32},
#   'bottomright': {'x': 1023, 'y': 119}},
#  {'label': 'green-pipe-up',
#   'confidence': 0.24181545,
#   'topleft': {'x': 65, 'y': 0},
#   'bottomright': {'x': 185, 'y': 336}},
#  {'label': 'green-pipe-up',
#   'confidence': 0.23296738,
#   'topleft': {'x': 357, 'y': 71},
#   'bottomright': {'x': 511, 'y': 427}},
#  {'label': 'green-pipe-up',
#   'confidence': 0.2255097,
#   'topleft': {'x': 705, 'y': 61},
#   'bottomright': {'x': 867, 'y': 445}},
#  {'label': 'green-pipe-up',
#   'confidence': 0.27530897,
#   'topleft': {'x': 1069, 'y': 48},
#   'bottomright': {'x': 1199, 'y': 480}},
#  {'label': 'green-pipe-down',
#   'confidence': 0.47488979,
#   'topleft': {'x': 529, 'y': 386},
#   'bottomright': {'x': 689, 'y': 728}},
#  {'label': 'green-pipe-down',
#   'confidence': 0.2716115,
#   'topleft': {'x': 885, 'y': 377},
#   'bottomright': {'x': 1052, 'y': 736}},
#  {'label': 'green-pipe-down',
#   'confidence': 0.70615435,
#   'topleft': {'x': 43, 'y': 575},
#   'bottomright': {'x': 195, 'y': 760}},
#  {'label': 'green-pipe-down',
#   'confidence': 0.66524345,
#   'topleft': {'x': 381, 'y': 676},
#   'bottomright': {'x': 468, 'y': 770}},
#  {'label': 'green-pipe-down',
#   'confidence': 0.6905398,
#   'topleft': {'x': 735, 'y': 687},
#   'bottomright': {'x': 832, 'y': 763}},
#  {'label': 'green-pipe-down',
#   'confidence': 0.669433,
#   'topleft': {'x': 1093, 'y': 724},
#   'bottomright': {'x': 1187, 'y': 770}}]

# %%
# pull out some info from the results

tl = (result[0]['topleft']['x'], result[0]['topleft']['y'])
br = (result[0]['bottomright']['x'], result[0]['bottomright']['y'])
label = result[0]['label']


# add the box and label and display it
img = cv2.rectangle(img, tl, br, (0, 255, 0), 7) # draw a ractangle onto an image
img = cv2.putText(img, label, tl, cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 0), 2) # add laebl name
plt.imshow(img)
plt.show()

# %%
import numpy as np

colors = [tuple(255 * np.random.rand(3)) for i in range(10)]
results = tfnet.return_predict(img)

for color, result in zip(colors, results):
    tl = (result['topleft']['x'], result['topleft']['y'])
    br = (result['bottomright']['x'], result['bottomright']['y'])
    label = result['label']
    frame = cv2.rectangle(img, tl, br, color, 7)
#     frame = cv2.putText(img, label, tl, cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 0), 2)
# cv2.imshow('frame', img)
plt.imshow(img)
plt.show()
